# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

# %%
data=pd.read_csv(r"C:\Users\imman\Downloads\1000_Companies.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        1000 non-null   float64
#  1   Administration   1000 non-null   float64
#  2   Marketing Spend  1000 non-null   float64
#  3   State            1000 non-null   object
#  4   Profit           1000 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 39.2+ KB

# %%
x = data[['R&D Spend', 'Administration', 'Marketing Spend']]
y=data['Profit']
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
r2s=r2_score(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
print(f"R2 Score : {r2s}\nMean Suare Error : {mse}")
plt.scatter(y_test,y_pred,color='green',label="Actual vs Predicted")
plt.xlabel("Actual")
plt.ylabel("predicted")
plt.legend()
plt.show()
# Out:
# R2 Score : 0.9828413651608124
# Mean Suare Error : 30222809.548696667

# %%
def manual():
 a=input("Do u want to find a prediction manualy(Y or N):").strip().upper()
 if a=='Y' :
  b=float(input("R&D Spend:"))
  c=float(input("Marketing Spend:"))
  d=float(input("Administration:"))
  m_input=pd.DataFrame([[b,c,d]],columns=x.columns)
  m_pred=model.predict(m_input)
  print(f"Predicted Profit: {m_pred}")
 elif a=='N':
  return
 else:
  print("Enter Valid Answer...!")
  manual()
manual()
# Out:
# Do u want to find a prediction manualy(Y or N): y
# R&D Spend: 546654
# Marketing Spend: 156
# Administration: 354
# Predicted Profit: [209820.42049045]
